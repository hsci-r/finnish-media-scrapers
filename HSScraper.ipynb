# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

driver = webdriver.Chrome(executable_path='/Users/xtoxtox/Downloads/chromedriver')

driver.get("http://www.hs.fi")
print(driver.title)

buttons = driver.find_elements_by_xpath("//*[contains(text(), 'Kirjaudu')]")

for btn in buttons:
    btn.click()
# Out:
# Uutiset | HS.fi
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-6-650ed770468a> in <module>
#      10
#      11 for btn in buttons:
# ---> 12     btn.click()
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# ~/.local/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
# ...

# %%
driver.close()
